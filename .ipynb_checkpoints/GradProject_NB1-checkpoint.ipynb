# %% [markdown]
# <h1> DS200A Computer Vision Assignment</h1>

# %% [markdown]
# <h2>  Part One: Data Input </h2>

# %% [markdown]
# <h3>  Import Statements </h3>

# %%
#Import anything you need here
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import matplotlib
import skimage
from skimage import data
from skimage import io
import os

# %%
cur_dir = os.getcwd()
cur_dir
# Out:
# '/Users/cuichangze/Desktop/UCB/200/data100-final-project-2019'

# %%
#Example of reading in a file

path = cur_dir + "/20_categories_training/20_categories_training/dog/"
filename = os.path.join(path, 'dog_0001.jpg')
dog = io.imread(filename)
skimage.io.imshow(dog)

plt.show()
filename2 = os.path.join(path, 'dog_0002.jpg')
cat = io.imread(filename2)
example_data_frame= pd.DataFrame()


example_data_frame['Pictures']=[dog, cat]
example_data_frame['Encoding']=[1,2]
example_data_frame
# Out:
#                                             Pictures  Encoding
# 0  [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...         1
# 1  [[[152, 147, 151], [151, 146, 150], [149, 144,...         2

# %% [markdown]
# <h4> Using the code for reference, take the given folder and create a dataframe with the picture object, and the encoding as listed below. </h4>
# 0=Airplanes, 1=Bear, 2=Blimp, 3=Comet, 4=Crab, 5=Dog, 6=Dolphin, 7=Giraffe, 8=Goat, 9=Gorilla, 10=Kangaroo, 11=Killer-Whale, 12=Leopards, 13=Llama, 14= Penguin, 15= Porcupine, 16=Teddy-Bear, 17=Triceratops, 18=Unicorn, 19=Zebra

# %%
h = {"airplanes":0, "bear":1, "blimp":2, "comet":3, "crab":4, "dog":5, "dolphin":6, "giraffe":7, "goat":8, "gorilla":9,
     "kangaroo":10, "killer-whale":11, "leopards":12, "llama":13, "penguin":14, "porcupine":15, "teddy-bear":16, "triceratops":17,
     "unicorn":18, "zebra":19}
def read_training_data(path):
    res = pd.DataFrame()
    #Fill this function out, should return a dataframe with picture object, and correct encoding
    for dir in os.listdir(path):
        animal_path = path + "/" + dir
        if os.path.isdir(animal_path):
            encoding = h[dir]
            for fname in os.listdir(animal_path):
                filepath = animal_path + "/" + fname
                image = io.imread(filename)
                res = res.append({"Pictures": image, "Encoding": encoding}, ignore_index=True)
    return res
    
def read_test_data(path):
    res = pd.DataFrame()
    for dir in os.listdir(path):
        filepath = path + "/" + dir
        image = io.imread(filename)
        res = res.append({"Pictures": image}, ignore_index=True)
    return res
    

train_dir = cur_dir + "/20_categories_training/20_categories_training"
train = read_training_data(train_dir)

test_dir = cur_dir + "/20_Validation"
test = read_test_data(test_dir)
# Out:
#                                               Pictures
# 0    [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
# 1    [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
# 2    [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
# 3    [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
# 4    [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
# ..                                                 ...
# 711  [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
# 712  [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
# 713  [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
# 714  [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
# 715  [[[46, 23, 17], [50, 27, 21], [55, 35, 28], [6...
#
# [716 rows x 1 columns]
